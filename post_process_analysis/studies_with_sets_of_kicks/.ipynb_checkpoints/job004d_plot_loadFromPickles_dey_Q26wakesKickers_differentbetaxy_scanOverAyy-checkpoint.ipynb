# %%
import sys
sys.path.append('../../../utils/')
from cmptTheoreticalEmitGrowth import *
from bunchLengthConversions import *
from coordinatesConversions import *
from cmpt_TuneSpreads import *

import numpy as np
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting parameters

# %%
params = {'legend.fontsize': 20,
          'figure.figsize': (9.5, 8.5),
          'axes.labelsize': 27,
          'axes.titlesize': 23,
          'xtick.labelsize': 27,
          'ytick.labelsize': 27,
          'image.cmap': 'jet',
          'lines.linewidth': 1,
          'lines.markersize': 10,
          'font.family': 'sans-serif'}

plt.rc('text', usetex=False)
plt.rc('font', family='serif')
plt.rcParams.update(params)

# %% [markdown]
# ### Study parameters

# %%
n_sets = 20
n_turns = int(1e5)            # number of cycles to run the simulation for
decTurns = int(100)           # how often to record data
circumference  = 6911.5623 # [m]
f_rev  = 299792458/circumference  # [Hz] The revolution frequency of the machine 
separationTime = 1 / f_rev * decTurns #There are decTurns revolutions before each recording of data
tspan = (np.arange(n_turns / decTurns) + 1.0) * separationTime #total time spanned by the simulation

# %%
my_variables_1 = list(np.arange(400.0,1.6e4,  800.0))
my_variables_1.insert(0,0.0)

my_variables_2 = list(np.arange(-2e4, 2.01e4, 2000.0))

print(f'variables for study 1: {my_variables_1} \n')
print(f'variables for study 2: {my_variables_2}')
# Out:
# variables for study 1: [0.0, 400.0, 1200.0, 2000.0, 2800.0, 3600.0, 4400.0, 5200.0, 6000.0, 6800.0, 7600.0, 8400.0, 9200.0, 10000.0, 10800.0, 11600.0, 12400.0, 13200.0, 14000.0, 14800.0, 15600.0]
#
# variables for study 2: [-20000.0, -18000.0, -16000.0, -14000.0, -12000.0, -10000.0, -8000.0, -6000.0, -4000.0, -2000.0, 0.0, 2000.0, 4000.0, 6000.0, 8000.0, 10000.0, 12000.0, 14000.0, 16000.0, 18000.0, 20000.0]

# %% [markdown]
# ### Load the data

# %%
path_to_data = './'
QpxQpy="1"
study_name = f'deyRates_sps_270GeV_CC_PN1e-8_1e5turns_5e5Nb_Q26kickersWakes_differentbetaxy_QpxQpy{QpxQpy}_ayyScanlong' # title for save figures
study_name_1 = f'deyRates_sps_270GeV_CC_PN1e-8_1e5turns_5e5Nb_wakefieldsON_500slices_QpxQpy{QpxQpy}_ayyScan'
study_name_2 = f'deyRates_sps_270GeV_CC_PN1e-8_1e5turns_5e5Nb_wakefieldsON_kickers_500slices_QpxQpy{QpxQpy}_ayyScan'
noise_type = 'PN'

my_df_1 = pickle.load( open(path_to_data+study_name_1+'.pkl', "rb" ))
my_df_2 = pickle.load( open(path_to_data+study_name_2+'.pkl', "rb" ) )

# %%
my_df_2
# Out:
#                                           ayy_-20000.0  \
# m    [2.5574627071965374e-08, 2.5874434813039083e-0...
# b    [1.998335564028658e-06, 1.997521277600149e-06,...
# err  [3.384819185849646e-11, 5.35490079181795e-11, ...
#
#                                           ayy_-18000.0  \
# m    [2.5563948112678596e-08, 2.5586497930277844e-0...
# b    [1.998473070436665e-06, 1.996017313105106e-06,...
# err  [3.297241905816002e-11, 6.173218432060047e-11,...
#
#                                           ayy_-16000.0  \
# m    [2.562176005158807e-08, 2.5754452796625674e-08...
# b    [1.9999550566358934e-06, 1.9994269440761514e-0...
# err  [3.3659265418336364e-11, 6.54914604157717e-11,...
#
#                                           ayy_-14000.0  \
# m    [2.6067425190653472e-08, 2.5747123279197907e-0...
# b    [2.0008602134800603e-06, 1.9969748102808808e-0...
# err  [3.645059163623967e-11, 7.266718634893024e-11,...
#
#                                           ayy_-12000.0  \
# ...

# %%
my_df_keys_1 = list(my_df_1.keys()) 
my_df_keys_2 = list(my_df_2.keys())
print(my_df_keys_1)
print(my_df_keys_2)
# Out:
# ['ayy_0.0', 'ayy_400.0', 'ayy_1200.0', 'ayy_2000.0', 'ayy_2800.0', 'ayy_3600.0', 'ayy_4400.0', 'ayy_5200.0', 'ayy_6000.0', 'ayy_6800.0', 'ayy_7600.0', 'ayy_8400.0', 'ayy_9200.0', 'ayy_10000.0', 'ayy_10800.0', 'ayy_11600.0', 'ayy_12400.0', 'ayy_13200.0', 'ayy_14000.0', 'ayy_14800.0', 'ayy_15600.0']
# ['ayy_-20000.0', 'ayy_-18000.0', 'ayy_-16000.0', 'ayy_-14000.0', 'ayy_-12000.0', 'ayy_-10000.0', 'ayy_-8000.0', 'ayy_-6000.0', 'ayy_-4000.0', 'ayy_-2000.0', 'ayy_0.0', 'ayy_2000.0', 'ayy_4000.0', 'ayy_6000.0', 'ayy_8000.0', 'ayy_10000.0', 'ayy_12000.0', 'ayy_14000.0', 'ayy_16000.0', 'ayy_18000.0', 'ayy_20000.0']

# %% [markdown]
# ### Compute error bars
#
# Let's assume:
#
# \begin{equation}
# y_1 = a_1 x \pm err_1 \\
# y_2 = a_2 x \pm err_2 \\
# y_3 = a_3 x \pm err_3
# \end{equation}
#
# where $a_1, a_2, a_3$ is the growth rates obtained from a linear fit on the simulation data and $err_1, err_2, err_3$ the error of the linear fit.
#
#
# Then the systematic error is:
# \begin{equation}
# systematic \ error = std({a_1, a_2, a_3})
# \end{equation}
#
# and the statistical errors:
# \begin{equation}
# statistical \ error = \sqrt{\langle {err_1^2, err_2^2. err_3^2} \rangle}
# \end{equation}.
#
# The total error is:
#
# \begin{equation}
# total \ error = \sqrt{(systematic \ error)^2 + (statistical \ error)^2}
# \end{equation}

# %%
beta_x_q20 = 54.65 #### (for Q20)
beta_y_q20 = 54.51 #### (for Q20)
beta_x_q26 = 42.0941 #### (for Q26)
beta_y_q26 = 42.0137 #### (for Q26)

for i, key in enumerate(my_df_keys_1):
    
    if i ==0:
        my_label_1 = r'$\mathrm{\langle \beta_x \rangle=}$'+f'{beta_x_q20} m, '+r'$\mathrm{\langle \beta_y \rangle}=$'+f'{beta_y_q20} m'
        my_label_2 = r'$\mathrm{\langle \beta_x \rangle =}$'+f'{beta_x_q26} m, '+r'$\mathrm{\langle \beta_y \rangle}=$'+f'{beta_y_q26} m'
    else:
        my_label_1 = my_label_2 = ''
        
    # errors for study 1
    systematic_error_1 = np.std(my_df_1[my_df_keys_1[i]]['m'])
    statistical_error_1 = np.sqrt(np.mean(np.array(my_df_1[my_df_keys_1[i]]['err'])**2))
    total_error_1 = np.sqrt(systematic_error_1**2+statistical_error_1**2)
    
    # errors for study 2
    systematic_error_2 = np.std(my_df_2[my_df_keys_2[i]]['m'])
    statistical_error_2 = np.sqrt(np.mean(np.array(my_df_2[my_df_keys_2[i]]['err'])**2))
    total_error_2 = np.sqrt(systematic_error_2**2+statistical_error_2**2)
    
    
    plt.errorbar(my_variables_1[i], np.mean(my_df_1[my_df_keys_1[i]]['m'])*1e9, yerr=total_error_1*1e9, marker='o',  c='C0', label=my_label_1)
    plt.errorbar(my_variables_2[i], np.mean(my_df_2[my_df_keys_2[i]]['m'])*1e9, yerr=total_error_2*1e9, marker='o',  c='C1', label=my_label_2)
    
    
plt.legend(loc=4)

plt.xlim(-200, 16000)
plt.ylim(0, 40)
plt.grid(linestyle='dashed')
plt.ylabel(r'$\mathrm{d\epsilon_y / dt \ (nm/s)}$')
plt.xlabel('Vertical detuning coefficient, '+r'$\mathrm{\alpha_{yy} \ (1/m)}$')

plt.title('Q26 kicker wakes')

plt.tight_layout()

savefig = False
if savefig:
    plt.savefig(f'./output/{study_name}.png', bbox_inches='tight')

# %% [markdown]
# ### Compute the theoretically expected rate

# %%
# Machine parameters
betay = 73.81671646 # 73 m at CC2, 76 m at CC1
Vcc = 1e6 # V
Eb = 270e9 # eV
gamma_0 = 287.8 
beta_0 = np.sqrt(1 - 1/gamma_0**2)
circumference = 6911.5623 # m
frev = 299792458/circumference # Hz
sigma_z = 0.155 # m
f_CC = 400.789e6 # CC frequency in Hz
clight = 299792458 # m/s
# Noise kick parameters
A_phase = 1e-8 # rms kick in the simulation of the phase noise
A_amplitude = 0 # rms kick in the simulation of the amplitude noise
scale_factor = Eb/Vcc # scaling factor to rms noise, σ
# Compute the PSD in rad^2/Hz and V^2/Hz
PSD_phi = (A_phase * scale_factor)**2/frev # rad^2/Hz
#PSD_phi = 1.42e-10
#PSD_phi = 1.4e-10
PSD_A = (A_amplitude * scale_factor)**2/frev # V^2/Hz
print(f'psd phi: {PSD_phi} rad^2/Hz, psd A: {PSD_A} V^2/Hz')
# Out:
# psd phi: 1.6806723392287607e-10 rad^2/Hz, psd A: 0.0 V^2/Hz

# %%
# Compute the correction factor due to the bunch length
sigma_phi = bunch_length_m_to_rad(sigma_z, clight, f_CC)
CDeltaphi = cmpt_bunch_length_correction_factor(sigma_phi, 'PN')
CDeltaA = cmpt_bunch_length_correction_factor(sigma_phi, 'AN')
print('CDeltaPhi = {}, CDeltaA = {}'.format(CDeltaphi, CDeltaA))

if noise_type == 'PN':
    expected_growth = emit_growth_phase_noise(betay, Vcc, frev, Eb, CDeltaphi, PSD_phi, one_sided_psd=False)*beta_0*gamma_0 # m/s
    my_color = 'C0'
    fill_bewtween_color = 'lightblue'
elif noise_type == 'AN':
    expected_growth = emit_growth_amplitude_noise(betay, Vcc, frev, Eb, CDeltaA, PSD_A, one_sided_psd=False)*beta_0*gamma_0 # m/s
    my_color = 'C1'
    fill_bewtween_color = 'moccasin'
else:
    my_color = 'C2'
    expected_growth_1 = emit_growth_phase_noise(betay, Vcc, frev, Eb, CDeltaphi, PSD_phi, one_sided_psd=False)*beta_0*gamma_0 # m/s
    expected_growth_2 = emit_growth_amplitude_noise(betay, Vcc, frev, Eb, CDeltaA, PSD_A, one_sided_psd=False)*beta_0*gamma_0 # m/s
    expected_growth = expected_growth_1 + expected_growth_2

print('expected growth = {} nm/s'.format(expected_growth*1e9))
# Out:
# CDeltaPhi = 0.5168486015622045, CDeltaA = 0.24157569921889774
# expected growth = 23.813362141833874 nm/s

# %%
beta_x_q20 = 54.65 #### (for Q20)
beta_y_q20 = 54.51 #### (for Q20)
beta_x_q26 = 42.0941 #### (for Q26)
beta_y_q26 = 42.0137 #### (for Q26)

for i, key in enumerate(my_df_keys_1):
    
    if i ==0:
        my_label_1 = r'$\mathrm{\langle \beta_x \rangle=}$'+f'{beta_x_q20} m, '+r'$\mathrm{\langle \beta_y \rangle}=$'+f'{beta_y_q20} m'
        my_label_2 = r'$\mathrm{\langle \beta_x \rangle =}$'+f'{beta_x_q26} m, '+r'$\mathrm{\langle \beta_y \rangle}=$'+f'{beta_y_q26} m'
    else:
        my_label_1 = my_label_2 = ''
        
    # errors for study 1
    systematic_error_1 = np.std(my_df_1[my_df_keys_1[i]]['m'])
    statistical_error_1 = np.sqrt(np.mean(np.array(my_df_1[my_df_keys_1[i]]['err'])**2))
    total_error_1 = np.sqrt(systematic_error_1**2+statistical_error_1**2)
    
    # errors for study 2
    systematic_error_2 = np.std(my_df_2[my_df_keys_2[i]]['m'])
    statistical_error_2 = np.sqrt(np.mean(np.array(my_df_2[my_df_keys_2[i]]['err'])**2))
    total_error_2 = np.sqrt(systematic_error_2**2+statistical_error_2**2)
    
    
    plt.errorbar(my_variables_1[i], np.mean(my_df_1[my_df_keys_1[i]]['m'])*1e9, yerr=total_error_1*1e9, marker='o',  c='C0', label=my_label_1)
    plt.errorbar(my_variables_2[i], np.mean(my_df_2[my_df_keys_2[i]]['m'])*1e9, yerr=total_error_2*1e9, marker='o',  c='C1', label=my_label_2)
    
plt.hlines(expected_growth*1e9, -500, 17000, linestyles='dashed', linewidth=3, color='k', label=f'theoretical growth = {expected_growth*1e9:.2f} nm/s')    
plt.legend(loc=4)

plt.xlim(-200, 17000)
plt.ylim(0, 40)
plt.grid(linestyle='dashed')
plt.ylabel(r'$\mathrm{d\epsilon_y / dt \ (nm/s)}$')
plt.xlabel('Vertical detuning coefficient, '+r'$\mathrm{\alpha_{yy} \ (1/m)}$')

plt.title('Q26 kicker wakes')

plt.tight_layout()

savefig = False
if savefig:
    plt.savefig(f'./output/{study_name}.png', bbox_inches='tight')

# %% [markdown]
# ### Compute the rms detuning with amplitude

# %%
#Load the bunch, you need to activate a Pyheadtail version v1.13 or newer
#path_to_bunch = '/afs/cern.ch/work/n/natriant/private/pyheadtail_example_crabcavity/'
path_to_bunch='./'
bunch = pickle.load(open(path_to_bunch+'bunch', 'rb')) # you need to activate an environment with pyhedtail version at least v1.13.5

# %%
# Optics at CC2
beta_y = 73.81671646
beta_x = 30.31164764
alpha_y = 0
alpha_x = 0

# Coordinates
x, px = bunch.x, bunch.xp
y, py =  bunch.y, bunch.yp

# Normalised coordinates 
x_n, px_n = cmpt_normalised_coordinates(x, px, beta_x, alpha_x)
y_n, py_n = cmpt_normalised_coordinates(y, py, beta_y, alpha_y)


# Compute actions
Jx_init = cmpt_actions(x_n, px_n)
Jy_init = cmpt_actions(y_n, py_n)

rms_Jx_init = np.std(Jx_init)
rms_Jy_init = np.std(Jy_init)

print(f'rms(Jx)={rms_Jx_init} m')
print(f'rms(Jy)={rms_Jy_init} m')
# Out:
# rms(Jx)=6.9400568591152065e-09 m
# rms(Jy)=6.936692592779671e-09 m

# %%
axy=0
Dqy_rms_1 = []
Dqy_rms_2 = []

for ayy in my_variables_1:
    Dqy_rms_1.append(rms_amplitude_detuning_y(Jy_init, Jx_init, ayy, axy))
for ayy in my_variables_2:
    Dqy_rms_2.append(rms_amplitude_detuning_y(Jy_init, Jx_init, ayy, axy))

# %%
fig, ax = plt.subplots(1,1)

ax2 = ax.twiny()

for i, key in enumerate(my_df_keys_1):
    
    if i ==0:
        my_label_1 = r'$\mathrm{\langle \beta_x \rangle=}$'+f'{beta_x_q20} m, '+r'$\mathrm{\langle \beta_y \rangle}=$'+f'{beta_y_q20} m'
        my_label_2 = r'$\mathrm{\langle \beta_x \rangle =}$'+f'{beta_x_q26} m, '+r'$\mathrm{\langle \beta_y \rangle}=$'+f'{beta_y_q26} m'
    else:
        my_label_1 = my_label_2 = ''
        
    # errors for study 1
    systematic_error_1 = np.std(my_df_1[my_df_keys_1[i]]['m'])
    statistical_error_1 = np.sqrt(np.mean(np.array(my_df_1[my_df_keys_1[i]]['err'])**2))
    total_error_1 = np.sqrt(systematic_error_1**2+statistical_error_1**2)
    
    # errors for study 2
    systematic_error_2 = np.std(my_df_2[my_df_keys_2[i]]['m'])
    statistical_error_2 = np.sqrt(np.mean(np.array(my_df_2[my_df_keys_2[i]]['err'])**2))
    total_error_2 = np.sqrt(systematic_error_2**2+statistical_error_2**2)
    
    
    ax.errorbar(my_variables_1[i], np.mean(my_df_1[my_df_keys_1[i]]['m'])*1e9, yerr=total_error_1*1e9, marker='o',  c='C0', label=my_label_1)
    ax.errorbar(my_variables_2[i], np.mean(my_df_2[my_df_keys_2[i]]['m'])*1e9, yerr=total_error_2*1e9, marker='o',  c='C1', label=my_label_2)
    
    
    ax2.plot(np.array(Dqy_rms_1[i])*1e4, np.mean(my_df_1[my_df_keys_1[i]]['m'])*1e9, linestyle='')
    ax2.plot(np.array(Dqy_rms_2[i])*1e4, np.mean(my_df_2[my_df_keys_2[i]]['m'])*1e9, linestyle='')


ax.hlines(expected_growth*1e9, -400, 17000, linestyles='dashed', linewidth=3, color='k', label=f'theoretical growth = {expected_growth*1e9:.2f} nm/s')
ax.legend(loc=4)

ax2.set_xlim(-2*300*rms_Jy_init*1e4, 2*17000*rms_Jy_init*1e4)
ax.set_xlim(-300, 17000)


ax.set_ylim(0, 40)
ax.grid(linestyle='dashed')

ax.set_ylabel(r'$\mathrm{\langle d\epsilon_y / dt \rangle \ [nm/s]}$')
ax.set_xlabel('Detuning coefficient, '+r'$\mathrm{\alpha_{yy} \ [1/m]}$')
ax.ticklabel_format(axis='x', style='sci', scilimits=(4,4))


ax2.set_xlabel(r'$\mathrm{rms(\Delta Q_y) \cdot 10^{-4}}$')

plt.tight_layout()

savefig = False
if savefig:
    plt.savefig(f'./output/{study_name}_vs_TuneSpread_v2.png', bbox_inches='tight')

# %% [markdown]
# ### Plot expected rms amplitude detuning of SPS for the current settings
# - b3b5b7 included
# - chroma match at the current setting (contribution from the chromatic sextupoles)
# - klof=klod=1 $1/m^4$
# - axy and ayy values as shown below are obtained from MAD-X

# %%
if QpxQpy=="0":
    axy_sps = -1484.124066 # for Qpx=Qpy=0
    ayy_sps = 1082.073444 # for Qpx=Qpy=0
elif QpxQpy=="5e-1":
    axy_sps = -1497.189826 # for Qpx=Qpy=0.5
    ayy_sps = 1081.203394 # for Qpx=Qpy=0.5
elif QpxQpy=="1":
    axy_sps = -1510.465536 # for Qpx=Qpy=1
    ayy_sps = 1080.331794 # for Qpx=Qpy=1
print(axy_sps, ayy_sps)
# Out:
# -1510.465536 1080.331794

# %%
Dqy_rms_sps = rms_amplitude_detuning_y(Jy_init, Jx_init, ayy_sps, axy_sps)
print(Dqy_rms_sps)
# Out:
# 2.5767755375923537e-05

# %%
fig, ax = plt.subplots(1,1)

ax2 = ax.twiny()

points_q20 = []
points_q26 = []

for i, key in enumerate(my_df_keys_1):
    
    if i ==0:
        my_label_1 = r'$\mathrm{\langle \beta_x \rangle=}$'+f'{beta_x_q20} m, '+r'$\mathrm{\langle \beta_y \rangle}=$'+f'{beta_y_q20} m'
        my_label_2 = r'$\mathrm{\langle \beta_x \rangle =}$'+f'{beta_x_q26} m, '+r'$\mathrm{\langle \beta_y \rangle}=$'+f'{beta_y_q26} m'
    else:
        my_label_1 = my_label_2 = ''
        
    # errors for study 1
    systematic_error_1 = np.std(my_df_1[my_df_keys_1[i]]['m'])
    statistical_error_1 = np.sqrt(np.mean(np.array(my_df_1[my_df_keys_1[i]]['err'])**2))
    total_error_1 = np.sqrt(systematic_error_1**2+statistical_error_1**2)
    
    # errors for study 2
    systematic_error_2 = np.std(my_df_2[my_df_keys_2[i]]['m'])
    statistical_error_2 = np.sqrt(np.mean(np.array(my_df_2[my_df_keys_2[i]]['err'])**2))
    total_error_2 = np.sqrt(systematic_error_2**2+statistical_error_2**2)
    
    
    ax.errorbar(my_variables_1[i], np.mean(my_df_1[my_df_keys_1[i]]['m'])*1e9, yerr=total_error_1*1e9, marker='o',  c='C0', label=my_label_1)
    ax.errorbar(my_variables_2[i], np.mean(my_df_2[my_df_keys_2[i]]['m'])*1e9, yerr=total_error_2*1e9, marker='o',  c='C1', label=my_label_2)
    
    points_q20.append(np.mean(my_df_1[my_df_keys_1[i]]['m'])*1e9)
    points_q26.append(np.mean(my_df_2[my_df_keys_2[i]]['m'])*1e9)
    
    
    ax2.plot(np.array(Dqy_rms_1[i])*1e4, np.mean(my_df_1[my_df_keys_1[i]]['m'])*1e9, linestyle='')


ax.hlines(expected_growth*1e9, -400, 17000, linestyles='dashed', linewidth=3, color='grey', label=f'theoretical growth = {expected_growth*1e9:.2f} nm/s')

ax.plot(my_variables_1, points_q20)
ax.plot(my_variables_2, points_q26)

# Plot SPS tune spread from MAD-X
ax2.plot(Dqy_rms_sps*1e4, 12.2, 'o', c='k', label=r'$\mathrm{rms(\Delta Qy)}=$'+f'{Dqy_rms_sps*1e4:.2f} '+r'$\mathrm{10^{-4}}$'+'\nexpected for SPS')
ax2.plot(Dqy_rms_sps*1e4, 11.3, 'o', c='k') 
ax2.vlines(Dqy_rms_sps*1e4, 11.3, 40, ls='dashed')

ax.legend(loc=4)
ax2.legend(loc=1)

ax2.set_xlim(-2*300*rms_Jy_init*1e4, 2*16000*rms_Jy_init*1e4)
ax.set_xlim(-300, 16000)

ax.set_ylim(0, 40)
ax.grid(linestyle='dashed')

ax.set_ylabel(r'$\mathrm{\langle d\epsilon_y / dt \rangle \ [nm/s]}$')
ax.set_xlabel('Detuning coefficient, '+r'$\mathrm{\alpha_{yy} \ [1/m]}$')
ax.ticklabel_format(axis='x', style='sci', scilimits=(4,4))


ax2.set_xlabel(r'$\mathrm{rms(\Delta Q_y) \cdot 10^{-4}}$')

plt.tight_layout()

savefig = False
if savefig:
    plt.savefig(f'./output/{study_name}_vs_TuneSpread_expectedSPS.png', bbox_inches='tight')
