# %%
import os, sys
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting parameters

# %%
params = {'legend.fontsize': 20,
          'figure.figsize': (9.5, 8.5),
          'axes.labelsize': 27,
          'axes.titlesize': 23,
          'xtick.labelsize': 27,
          'ytick.labelsize': 27,
          'image.cmap': 'jet',
          'lines.linewidth': 1,
          'lines.markersize': 10,
          'font.family': 'sans-serif'}

plt.rc('text', usetex=False)
plt.rc('font', family='serif')
plt.rcParams.update(params)

# %% [markdown]
# ### Study parameters

# %%
n_sets=20
n_runs=3
n_turns = int(1e5)            # number of cycles to run the simulation for
decTurns = int(100)           # how often to record data
circumference  = 6911.5623 # [m]
f_rev  = 299792458/circumference  # [Hz] The revolution frequency of the machine 
separationTime = 1 / f_rev * decTurns #There are decTurns revolutions before each recording of data
tspan = (np.arange(n_turns / decTurns) + 1.0) * separationTime #total time spanned by the simulationpan)

# %%
my_variables=list(np.linspace(0.0, 0.3, 25))
print(my_variables)
# Out:
# [0.0, 0.012499999999999999, 0.024999999999999998, 0.0375, 0.049999999999999996, 0.06249999999999999, 0.075, 0.0875, 0.09999999999999999, 0.11249999999999999, 0.12499999999999999, 0.13749999999999998, 0.15, 0.16249999999999998, 0.175, 0.18749999999999997, 0.19999999999999998, 0.2125, 0.22499999999999998, 0.2375, 0.24999999999999997, 0.26249999999999996, 0.27499999999999997, 0.2875, 0.3]

# %%
QpxQpy=0
wakes='ON'


path_to_data = f'./tbt_data/ayy-6000'
study_name='y'

# %%
ex_mean_dict, ey_mean_dict = {}, {} # type: dictionary
ex_std_dict, ey_std_dict = {}, {} # type: dictionary


for var in my_variables: # iterate over ayy
    for my_set in range(n_sets): # iterate over sets
        temp_name = f'{var}_set{my_set}'
        ex_mean, ey_mean = [], []
        for run in range(n_runs): # iterate over runs, compute mean
            try:
                meanX, meanY, meanXsq, meanYsq, emitX, emitY = np.loadtxt(path_to_data+f'/file_intensity{var}_set{my_set}_run{run}.txt', delimiter = ",", unpack = True)
                # B1. Create a different list for each run and save the emittance values
                ex_mean.append(emitX)
                ey_mean.append(emitY)
            except OSError as err:
                print("OS error: {0}".format(err))
        ex_mean_dict[temp_name] = np.mean(ex_mean, axis=0) # mean of the 3 runs
        ey_mean_dict[temp_name] = np.mean(ey_mean, axis=0)
        ex_std_dict[temp_name] = np.std(ex_mean, axis=0) # 1 std between the 3 runs
        ey_std_dict[temp_name] = np.std(ey_mean, axis=0)
# Out:
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set3_run0.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set3_run1.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set3_run2.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set4_run0.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set4_run1.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set4_run2.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set5_run0.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set5_run1.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set5_run2.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set6_run2.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set7_run1.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set7_run2.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set8_run1.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set8_run2.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set9_run1.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity8333333333.333333_set9_run2.txt not found.
# OS error: ./tbt_data/ayy-6000/file_intensity50000000000.0_set1_run2.txt not found.

# %% [markdown]
# ### Exclude the first two turns from the polyfit, as a sudden jump in the emittance is observed.

# %%
plt.plot(ey_mean_dict[temp_name], label='all')
plt.plot(ey_mean_dict[temp_name][2:], label='rm 2 first turns')
plt.legend()

# %%
m_dict = {} # slope of the fit
b_dict = {} # offset
err_dict = {} # error of the gradient of the fit slope

for var in my_variables:
    m_dict[f'{var}'], b_dict[f'{var}'], err_dict[f'{var}'] = [], [], []
    for my_set in range(n_sets):
        temp_name = f'{var}_set{my_set}'
        print(temp_name)
        # linear fit
        
        try:
            [m, b], cov = np.polyfit(tspan, ey_mean_dict[temp_name], 1, cov=True)
            # compute the error of the gradient of the fit slope
            err= np.sqrt(np.diag(cov))
            m_dict[f'{var}'].append(m) # len(m_dict[f'{var}']) = n_runs
            b_dict[f'{var}'].append(b)
            err_dict[f'{var}'].append(err[0])
        except (RuntimeError, TypeError, NameError) as err:
            print("OS error: {0}".format(err))
# Out:
# 0.0_set0
# 0.0_set1
# 0.0_set2
# 0.0_set3
# 0.0_set4
# 0.0_set5
# 0.0_set6
# 0.0_set7
# 0.0_set8
# 0.0_set9
# 0.0_set10
# 0.0_set11
# 0.0_set12
# 0.0_set13
# 0.0_set14
# 0.0_set15
# 0.0_set16
# 0.0_set17
# 0.0_set18
# 0.0_set19
# 2083333333.3333333_set0
# 2083333333.3333333_set1
# 2083333333.3333333_set2
# 2083333333.3333333_set3
# 2083333333.3333333_set4
# 2083333333.3333333_set5
# 2083333333.3333333_set6
# 2083333333.3333333_set7
# 2083333333.3333333_set8
# 2083333333.3333333_set9
# 2083333333.3333333_set10
# 2083333333.3333333_set11
# 2083333333.3333333_set12
# 2083333333.3333333_set13
# 2083333333.3333333_set14
# 2083333333.3333333_set15
# 2083333333.3333333_set16
# 2083333333.3333333_set17
# 2083333333.3333333_set18
# 2083333333.3333333_set19
# 4166666666.6666665_set0
# 4166666666.6666665_set1
# 4166666666.6666665_set2
# 4166666666.6666665_set3
# 4166666666.6666665_set4
# 4166666666.6666665_set5
# 4166666666.6666665_set6
# 4166666666.6666665_set7
# 4166666666.6666665_set8
# 4166666666.6666665_set9
# 4166666666.6666665_set10
# 4166666666.6666665_set11
# 4166666666.6666665_set12
# 4166666666.6666665_set13
# 4166666666.6666665_set14
# 4166666666.6666665_set15
# 4166666666.6666665_set16
# 4166666666.6666665_set17
# 4166666666.6666665_set18
# 4166666666.6666665_set19
# 6250000000.0_set0
# 6250000000.0_set1
# 6250000000.0_set2
# 6250000000.0_set3
# 6250000000.0_set4
# 6250000000.0_set5
# 6250000000.0_set6
# 6250000000.0_set7
# 6250000000.0_set8
# 6250000000.0_set9
# 6250000000.0_set10
# 6250000000.0_set11
# 6250000000.0_set12
# 6250000000.0_set13
# 6250000000.0_set14
# 6250000000.0_set15
# 6250000000.0_set16
# 6250000000.0_set17
# 6250000000.0_set18
# 6250000000.0_set19
# 8333333333.333333_set0
# 8333333333.333333_set1
# 8333333333.333333_set2
# 8333333333.333333_set3
# OS error: expected 1D or 2D array for y
# 8333333333.333333_set4
# OS error: expected 1D or 2D array for y
# 8333333333.333333_set5
# OS error: expected 1D or 2D array for y
# 8333333333.333333_set6
# 8333333333.333333_set7
# 8333333333.333333_set8
# 8333333333.333333_set9
# 8333333333.333333_set10
# 8333333333.333333_set11
# 8333333333.333333_set12
# 8333333333.333333_set13
# 8333333333.333333_set14
# 8333333333.333333_set15
# 8333333333.333333_set16
# 8333333333.333333_set17
# 8333333333.333333_set18
# 8333333333.333333_set19
# 10416666666.666666_set0
# 10416666666.666666_set1
# 10416666666.666666_set2
# 10416666666.666666_set3
# 10416666666.666666_set4
# 10416666666.666666_set5
# 10416666666.666666_set6
# 10416666666.666666_set7
# 10416666666.666666_set8
# 10416666666.666666_set9
# 10416666666.666666_set10
# 10416666666.666666_set11
# 10416666666.666666_set12
# 10416666666.666666_set13
# 10416666666.666666_set14
# 10416666666.666666_set15
# 10416666666.666666_set16
# 10416666666.666666_set17
# 10416666666.666666_set18
# 10416666666.666666_set19
# 12500000000.0_set0
# 12500000000.0_set1
# 12500000000.0_set2
# 12500000000.0_set3
# 12500000000.0_set4
# 12500000000.0_set5
# 12500000000.0_set6
# 12500000000.0_set7
# 12500000000.0_set8
# 12500000000.0_set9
# 12500000000.0_set10
# 12500000000.0_set11
# 12500000000.0_set12
# 12500000000.0_set13
# 12500000000.0_set14
# 12500000000.0_set15
# 12500000000.0_set16
# 12500000000.0_set17
# 12500000000.0_set18
# 12500000000.0_set19
# 14583333333.333332_set0
# 14583333333.333332_set1
# 14583333333.333332_set2
# 14583333333.333332_set3
# 14583333333.333332_set4
# 14583333333.333332_set5
# 14583333333.333332_set6
# 14583333333.333332_set7
# 14583333333.333332_set8
# 14583333333.333332_set9
# 14583333333.333332_set10
# 14583333333.333332_set11
# 14583333333.333332_set12
# 14583333333.333332_set13
# 14583333333.333332_set14
# 14583333333.333332_set15
# 14583333333.333332_set16
# 14583333333.333332_set17
# 14583333333.333332_set18
# 14583333333.333332_set19
# 16666666666.666666_set0
# 16666666666.666666_set1
# 16666666666.666666_set2
# 16666666666.666666_set3
# 16666666666.666666_set4
# 16666666666.666666_set5
# 16666666666.666666_set6
# 16666666666.666666_set7
# 16666666666.666666_set8
# 16666666666.666666_set9
# 16666666666.666666_set10
# 16666666666.666666_set11
# 16666666666.666666_set12
# 16666666666.666666_set13
# 16666666666.666666_set14
# 16666666666.666666_set15
# 16666666666.666666_set16
# 16666666666.666666_set17
# 16666666666.666666_set18
# 16666666666.666666_set19
# 18750000000.0_set0
# 18750000000.0_set1
# 18750000000.0_set2
# 18750000000.0_set3
# 18750000000.0_set4
# 18750000000.0_set5
# 18750000000.0_set6
# 18750000000.0_set7
# 18750000000.0_set8
# 18750000000.0_set9
# 18750000000.0_set10
# 18750000000.0_set11
# 18750000000.0_set12
# 18750000000.0_set13
# 18750000000.0_set14
# 18750000000.0_set15
# 18750000000.0_set16
# 18750000000.0_set17
# 18750000000.0_set18
# 18750000000.0_set19
# 20833333333.333332_set0
# 20833333333.333332_set1
# 20833333333.333332_set2
# 20833333333.333332_set3
# 20833333333.333332_set4
# 20833333333.333332_set5
# 20833333333.333332_set6
# 20833333333.333332_set7
# 20833333333.333332_set8
# 20833333333.333332_set9
# 20833333333.333332_set10
# 20833333333.333332_set11
# 20833333333.333332_set12
# 20833333333.333332_set13
# 20833333333.333332_set14
# 20833333333.333332_set15
# 20833333333.333332_set16
# 20833333333.333332_set17
# 20833333333.333332_set18
# 20833333333.333332_set19
# 22916666666.666664_set0
# 22916666666.666664_set1
# 22916666666.666664_set2
# 22916666666.666664_set3
# 22916666666.666664_set4
# 22916666666.666664_set5
# 22916666666.666664_set6
# 22916666666.666664_set7
# 22916666666.666664_set8
# 22916666666.666664_set9
# 22916666666.666664_set10
# 22916666666.666664_set11
# 22916666666.666664_set12
# 22916666666.666664_set13
# 22916666666.666664_set14
# 22916666666.666664_set15
# 22916666666.666664_set16
# 22916666666.666664_set17
# 22916666666.666664_set18
# 22916666666.666664_set19
# 25000000000.0_set0
# 25000000000.0_set1
# 25000000000.0_set2
# 25000000000.0_set3
# 25000000000.0_set4
# 25000000000.0_set5
# 25000000000.0_set6
# 25000000000.0_set7
# 25000000000.0_set8
# 25000000000.0_set9
# 25000000000.0_set10
# 25000000000.0_set11
# 25000000000.0_set12
# 25000000000.0_set13
# 25000000000.0_set14
# 25000000000.0_set15
# 25000000000.0_set16
# 25000000000.0_set17
# 25000000000.0_set18
# 25000000000.0_set19
# 27083333333.333332_set0
# 27083333333.333332_set1
# 27083333333.333332_set2
# 27083333333.333332_set3
# 27083333333.333332_set4
# 27083333333.333332_set5
# 27083333333.333332_set6
# 27083333333.333332_set7
# 27083333333.333332_set8
# 27083333333.333332_set9
# 27083333333.333332_set10
# 27083333333.333332_set11
# 27083333333.333332_set12
# 27083333333.333332_set13
# 27083333333.333332_set14
# 27083333333.333332_set15
# 27083333333.333332_set16
# 27083333333.333332_set17
# 27083333333.333332_set18
# 27083333333.333332_set19
# 29166666666.666664_set0
# 29166666666.666664_set1
# 29166666666.666664_set2
# 29166666666.666664_set3
# 29166666666.666664_set4
# 29166666666.666664_set5
# 29166666666.666664_set6
# 29166666666.666664_set7
# 29166666666.666664_set8
# 29166666666.666664_set9
# 29166666666.666664_set10
# 29166666666.666664_set11
# 29166666666.666664_set12
# 29166666666.666664_set13
# 29166666666.666664_set14
# 29166666666.666664_set15
# 29166666666.666664_set16
# 29166666666.666664_set17
# 29166666666.666664_set18
# 29166666666.666664_set19
# 31250000000.0_set0
# 31250000000.0_set1
# 31250000000.0_set2
# 31250000000.0_set3
# 31250000000.0_set4
# 31250000000.0_set5
# 31250000000.0_set6
# 31250000000.0_set7
# 31250000000.0_set8
# 31250000000.0_set9
# 31250000000.0_set10
# 31250000000.0_set11
# 31250000000.0_set12
# 31250000000.0_set13
# 31250000000.0_set14
# 31250000000.0_set15
# 31250000000.0_set16
# 31250000000.0_set17
# 31250000000.0_set18
# 31250000000.0_set19
# 33333333333.333332_set0
# 33333333333.333332_set1
# 33333333333.333332_set2
# 33333333333.333332_set3
# 33333333333.333332_set4
# 33333333333.333332_set5
# 33333333333.333332_set6
# 33333333333.333332_set7
# 33333333333.333332_set8
# 33333333333.333332_set9
# 33333333333.333332_set10
# 33333333333.333332_set11
# 33333333333.333332_set12
# 33333333333.333332_set13
# 33333333333.333332_set14
# 33333333333.333332_set15
# 33333333333.333332_set16
# 33333333333.333332_set17
# 33333333333.333332_set18
# 33333333333.333332_set19
# 35416666666.666664_set0
# 35416666666.666664_set1
# 35416666666.666664_set2
# 35416666666.666664_set3
# 35416666666.666664_set4
# 35416666666.666664_set5
# 35416666666.666664_set6
# 35416666666.666664_set7
# 35416666666.666664_set8
# 35416666666.666664_set9
# 35416666666.666664_set10
# 35416666666.666664_set11
# 35416666666.666664_set12
# 35416666666.666664_set13
# 35416666666.666664_set14
# 35416666666.666664_set15
# 35416666666.666664_set16
# 35416666666.666664_set17
# 35416666666.666664_set18
# 35416666666.666664_set19
# 37500000000.0_set0
# 37500000000.0_set1
# 37500000000.0_set2
# 37500000000.0_set3
# 37500000000.0_set4
# 37500000000.0_set5
# 37500000000.0_set6
# 37500000000.0_set7
# 37500000000.0_set8
# 37500000000.0_set9
# 37500000000.0_set10
# 37500000000.0_set11
# 37500000000.0_set12
# 37500000000.0_set13
# 37500000000.0_set14
# 37500000000.0_set15
# 37500000000.0_set16
# 37500000000.0_set17
# 37500000000.0_set18
# 37500000000.0_set19
# 39583333333.33333_set0
# 39583333333.33333_set1
# 39583333333.33333_set2
# 39583333333.33333_set3
# 39583333333.33333_set4
# 39583333333.33333_set5
# 39583333333.33333_set6
# 39583333333.33333_set7
# 39583333333.33333_set8
# 39583333333.33333_set9
# 39583333333.33333_set10
# 39583333333.33333_set11
# 39583333333.33333_set12
# 39583333333.33333_set13
# 39583333333.33333_set14
# 39583333333.33333_set15
# 39583333333.33333_set16
# 39583333333.33333_set17
# 39583333333.33333_set18
# 39583333333.33333_set19
# 41666666666.666664_set0
# 41666666666.666664_set1
# 41666666666.666664_set2
# 41666666666.666664_set3
# 41666666666.666664_set4
# 41666666666.666664_set5
# 41666666666.666664_set6
# 41666666666.666664_set7
# 41666666666.666664_set8
# 41666666666.666664_set9
# 41666666666.666664_set10
# 41666666666.666664_set11
# 41666666666.666664_set12
# 41666666666.666664_set13
# 41666666666.666664_set14
# 41666666666.666664_set15
# 41666666666.666664_set16
# 41666666666.666664_set17
# 41666666666.666664_set18
# 41666666666.666664_set19
# 43750000000.0_set0
# 43750000000.0_set1
# 43750000000.0_set2
# 43750000000.0_set3
# 43750000000.0_set4
# 43750000000.0_set5
# 43750000000.0_set6
# 43750000000.0_set7
# 43750000000.0_set8
# 43750000000.0_set9
# 43750000000.0_set10
# 43750000000.0_set11
# 43750000000.0_set12
# 43750000000.0_set13
# 43750000000.0_set14
# 43750000000.0_set15
# 43750000000.0_set16
# 43750000000.0_set17
# 43750000000.0_set18
# 43750000000.0_set19
# 45833333333.33333_set0
# 45833333333.33333_set1
# 45833333333.33333_set2
# 45833333333.33333_set3
# 45833333333.33333_set4
# 45833333333.33333_set5
# 45833333333.33333_set6
# 45833333333.33333_set7
# 45833333333.33333_set8
# 45833333333.33333_set9
# 45833333333.33333_set10
# 45833333333.33333_set11
# 45833333333.33333_set12
# 45833333333.33333_set13
# 45833333333.33333_set14
# 45833333333.33333_set15
# 45833333333.33333_set16
# 45833333333.33333_set17
# 45833333333.33333_set18
# 45833333333.33333_set19
# 47916666666.666664_set0
# 47916666666.666664_set1
# 47916666666.666664_set2
# 47916666666.666664_set3
# 47916666666.666664_set4
# 47916666666.666664_set5
# 47916666666.666664_set6
# 47916666666.666664_set7
# 47916666666.666664_set8
# 47916666666.666664_set9
# 47916666666.666664_set10
# 47916666666.666664_set11
# 47916666666.666664_set12
# 47916666666.666664_set13
# 47916666666.666664_set14
# 47916666666.666664_set15
# 47916666666.666664_set16
# 47916666666.666664_set17
# 47916666666.666664_set18
# 47916666666.666664_set19
# 50000000000.0_set0
# 50000000000.0_set1
# 50000000000.0_set2
# 50000000000.0_set3
# 50000000000.0_set4
# 50000000000.0_set5
# 50000000000.0_set6
# 50000000000.0_set7
# 50000000000.0_set8
# 50000000000.0_set9
# 50000000000.0_set10
# 50000000000.0_set11
# 50000000000.0_set12
# 50000000000.0_set13
# 50000000000.0_set14
# 50000000000.0_set15
# 50000000000.0_set16
# 50000000000.0_set17
# 50000000000.0_set18
# 50000000000.0_set19

# %%
for i, var in enumerate(my_variables):
        
    # errors for study 1
    systematic_error_1 = np.std(m_dict[f'{var}'])
    statistical_error_1 = np.sqrt(np.mean(np.array(err_dict[f'{var}'])**2))
    total_error_1 = np.sqrt(systematic_error_1**2+statistical_error_1**2)
    
 
    plt.errorbar(my_variables[i], np.mean(m_dict[f'{var}'])*1e9, yerr=total_error_1*1e9, marker='o',  c='k')#, label=my_label_1)
    
plt.xlabel('Intensity')
plt.ylabel(r'$\mathrm{\langle d\epsilon_y / dt \rangle \ [nm/s] }$')

plt.ylim(0, 40)
plt.grid(linestyle='dashed')


plt.tight_layout()

savefig = True
if savefig:
    plt.savefig(f'./figures/{study_name}.png', bbox_inches='tight')
