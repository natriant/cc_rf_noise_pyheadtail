# %% [markdown]
# ### Average over multiple runs  - Phase or amplirude noise -  Method 1
# Plot the emittance growth in the presence of phase noise - PN. The simulation for each set of parameters is repeated multiple times. The mean and the standard deviation of the emittance values are computed over all runs (part 3) for each turn. The normalised emittance is used here.

# %%
import sys
sys.path.append('../../utils/')
from cmptTheoreticalEmitGrowth import *
from bunchLengthConversions import *
import csv
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plotting paramerters

# %%
params = {'legend.fontsize': 20,
          'figure.figsize': (14.5, 11.5),
          'axes.labelsize': 27,
          'axes.titlesize': 25,
          'xtick.labelsize': 27,
          'ytick.labelsize': 27,
          'image.cmap': 'jet',
          'lines.linewidth': 2,
          'lines.markersize': 5,
          'font.family': 'sans-serif'}

plt.rc('text', usetex=False)
plt.rc('font', family='serif')
plt.rcParams.update(params)

# %% [markdown]
# #### 1) Load the data
# a) Give the paths to the data folder
#
# b) Load the values of the transverse emittances in lists.

# %%
n_runs = 3 # number of runs that the simulation was repeated
n_turns = int(1e5)            # number of cycles to run the simulation for
decTurns = int(100)           # how often to record data
circumference  = 6911.5623 # [m]
f_rev  = 299792458/circumference  # [Hz] The revolution frequency of the machine 
separationTime = 1 / f_rev * decTurns #There are decTurns revolutions before each recording of data
tspan = (np.arange(n_turns / decTurns) + 1.0) * separationTime #total time spanned by the simulation

# %%
my_start = 400.0 #9.6e3 #400.0
my_stop =  1e4#1.6e4 #1.6e4
my_step = 800.0

my_variables = list(np.arange(my_start, my_stop, my_step))
#my_variables.insert(0, 0.0)
print(my_variables)
print(len(my_variables))
# Out:
# [400.0, 1200.0, 2000.0, 2800.0, 3600.0, 4400.0, 5200.0, 6000.0, 6800.0, 7600.0, 8400.0, 9200.0]
# 12

# %%
path_to_data = '/afs/cern.ch/work/n/natriant/private/pyheadtail_example_crabcavity/'
study_name = 'sps_270GeV_CC_PN1e-8_1e5turns_5e5Nb_Nowakefields_vs_wakefieldsON_500slices'
study_name_1 = 'sps_270GeV_CC_PN1e-8_1e5turns_5e5Nb_Nowakefields_ayy'
study_name_2 ='sps_270GeV_CC_PN1e-8_1e5turns_5e5Nb_wakefieldsON_500slices_ayy' 
noise_type = 'PN'

# %%
ex_dict_1, ey_dict_1 = {}, {} # type: dictionary
ex_dict_2, ey_dict_2 = {}, {} # type: dictionary

#meanX_dict, meanY_dict = {}, {}


for var in my_variables:
    for run in range(n_runs):
        print(var, run)
        temp_name = f'{var}_run{run}' # the suffix of the name of the current study
        # A1. Load the data - study 1
        meanX, meanY, meanXsq, meanYsq, emitX, emitY = np.loadtxt(path_to_data+f'{study_name_1}{var}_run{run}/file.txt', delimiter = ",", unpack = True)
        # B1. Create a different list for each run and save the emittance values
        ex_dict_1[temp_name] = emitX 
        ey_dict_1[temp_name] = emitY
        
        # A2. Load the data - study 2
        meanX, meanY, meanXsq, meanYsq, emitX, emitY = np.loadtxt(path_to_data+f'{study_name_2}{var}_run{run}/file.txt', delimiter = ",", unpack = True)
        # B2. Create a different list for each run and save the emittance values
        ex_dict_2[temp_name] = emitX 
        ey_dict_2[temp_name] = emitY
# Out:
# 400.0 0
# 400.0 1
# 400.0 2
# 1200.0 0
# 1200.0 1
# 1200.0 2
# 2000.0 0
# 2000.0 1
# 2000.0 2
# 2800.0 0
# 2800.0 1
# 2800.0 2
# 3600.0 0
# 3600.0 1
# 3600.0 2
# 4400.0 0
# 4400.0 1
# 4400.0 2
# 5200.0 0
# 5200.0 1
# 5200.0 2
# 6000.0 0
# 6000.0 1
# 6000.0 2
# 6800.0 0
# 6800.0 1
# 6800.0 2
# 7600.0 0
# 7600.0 1
# 7600.0 2
# 8400.0 0
# 8400.0 1
# 8400.0 2
# 9200.0 0
# 9200.0 1
# 9200.0 2

# %% [markdown]
# ### Plotting - V and H plane

# %%
savefig = False
for var in my_variables:
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
    fig.suptitle(r'$\mathrm{\alpha_{yy}=}$'+f'{var} 1/m', fontsize=25)
    for run in range(n_runs):
        temp_name = f'{var}_run{run}' # the suffix of the name of the current study
        # study 1 - no wakes
        ax1.plot(tspan, ey_dict_1[temp_name]/ey_dict_1[temp_name][0])
        ax3.plot(tspan, ex_dict_1[temp_name]/ex_dict_1[temp_name][0])
        # study 2 - wakes
        ax2.plot(tspan, ey_dict_2[temp_name]/ey_dict_2[temp_name][0])
        ax4.plot(tspan, ex_dict_2[temp_name]/ex_dict_2[temp_name][0])
        
        
        # labels 
        ax1.set_ylabel(r'$\mathrm{\epsilon_y / \epsilon_{y0}}$')
        ax3.set_ylabel(r'$\mathrm{\epsilon_x / \epsilon_{x0}}$')
        ax2.set_ylabel(r'$\mathrm{\epsilon_y / \epsilon_{y0}}$')
        ax4.set_ylabel(r'$\mathrm{\epsilon_x / \epsilon_{x0}}$')
        
        
        ax1.set_title('Without wakes')
        ax2.set_title('With wakes')
        
        
        
        ax1.set_ylim(0.999, 1.05)
        ax2.set_ylim(0.999, 1.05)
        
        ax3.set_ylim(1-5e-5, 1+5e-5)
        ax4.set_ylim(1-5e-5, 1+5e-5)
        
        ax3.ticklabel_format(axis='both', style='sci', scilimits=(0,0))
        ax4.ticklabel_format(axis='both', style='sci', scilimits=(0,0))
        
        
        ax1.grid(linestyle='dashed')
        ax2.grid(linestyle='dashed')
        ax3.grid(linestyle='dashed')
        ax4.grid(linestyle='dashed')
        
        plt.subplots_adjust(wspace=0.4, hspace=0.4)
        
    if savefig:    
        plt.savefig(f'output/{study_name}_{var}.png')
    plt.close()

# %% [markdown]
# ###  Option to add the linear fit - not fully done yet

# %%
# linear fit
var = 500
[m_pn, b_pn], cov_pn = np.polyfit(tspan, ex_mean[f'{var}'], 1, cov=True)
# compute the error of the gradient of the fit slope
err_pn = np.sqrt(np.diag(cov_pn))

# %%
plt.plot(tspan, np.array(ex_mean[f'{var}'])*1e6, c='C0')
plt.plot(tspan, (m_pn*tspan+b_pn)*1e6, c = 'C0', label=r'$\mathrm{d\epsilon y/dt}$'+'={0:.2f}'.format(m_pn*1e9)+'$\pm$'+'{0:.2f} nm/s'.format(err_pn[0]*1e9), linewidth = 3)

plt.xlabel('time [s]')
plt.ylabel(r'$\epsilon_x [\mu m]$')
plt.legend(loc=0)
plt.grid()
plt.tight_layout()
savefig = False
if savefig:
    plt.savefig(f'./output/dex_{study_name}_{noise_type}_runs{n_runs}_iterate{titleLegend}.png')
