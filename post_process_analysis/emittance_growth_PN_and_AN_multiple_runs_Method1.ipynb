# %% [markdown]
# ### Average over multiple runs  - Method 1
# Plot the emittance growth in the presence of phase and amplitude noise (PN and AN respectively). The simulation for each set of parameters is repeated multiple times. The mean and the standard deviation of the emittance values are computed over all runs (part 3) for each turn. The normalised emittance is used here.

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plotting paramerters

# %%
params = {'legend.fontsize': 20,
          'figure.figsize': (9.5, 8.5),
          'axes.labelsize': 27,
          'axes.titlesize': 23,
          'xtick.labelsize': 27,
          'ytick.labelsize': 27,
          'image.cmap': 'jet',
          'lines.linewidth': 2,
          'lines.markersize': 5,
          'font.family': 'sans-serif'}

plt.rc('text', usetex=False)
plt.rc('font', family='serif')
plt.rcParams.update(params)

# %% [markdown]
# #### 1) Load the data
# a) Give the paths to the data in /afs/.
#
# b) Load the values of the transverse emittance in a dictionary.

# %%
n_runs = 30 # number of runs that the simulation was repeated
n_turns = int(3e5)            # number of cycles to run the simulation for
decTurns = int(100)           # how often to record data
circumference  = 6911.5623 # [m]
f_rev           = 299792458/circumference  # [Hz] The revolution frequency of the machine

# %%
path_to_data = '/afs/cern.ch/work/n/natriant/private/pyheadtail_example_crabcavity/'
PN_name_template = 'PN_mytest'
AN_name_template = 'AN_mytest'

# %%
# phase noise
ex_dict_pn = {} # type: dictionary
ey_dict_pn = {}
# amplitude noise
ex_dict_an = {} # type: dictionary
ey_dict_an = {} 
for run in range(n_runs):
    temp_name = 'run{}'.format(run+1) # the suffix of the name of the current study
    # A. load the turn by turn data in a dictionary
    meanX_pn, meanY_pn, meanXsq_pn, meanYsq_pn, emitX_pn, emitY_pn = np.loadtxt(path_to_data+PN_name_template+'{}'.format(run+1)+'/file.txt', delimiter = ",", unpack = True)
    meanX_an, meanY_an, meanXsq_an, meanYsq_an, emitX_an, emitY_an = np.loadtxt(path_to_data+AN_name_template+'{}'.format(run+1)+'/file.txt', delimiter = ",", unpack = True)
    # B. Create a different list for each run and save the emittance values
    ex_dict_pn[temp_name] = emitX_pn # PN
    ey_dict_pn[temp_name] = emitY_pn
    ex_dict_an[temp_name] = emitX_an # AN
    ey_dict_an[temp_name] = emitY_an

# %% [markdown]
# #### 2) Here the mean and the standard deviation of the emittance values are computed over all runs.

# %%
ex_mean_pn = []
ey_mean_pn = []
ex_mean_an = []
ey_mean_an = []

ex_std_pn = []
ey_std_pn = []
ex_std_an = []
ey_std_an = []


n_saved_turns = int(n_turns/decTurns)

for turn in range(n_saved_turns):
    ex_temp_pn = []
    ey_temp_pn = []
    ex_temp_an = []
    ey_temp_an = []
    # keep all the emittance values for all the runs
    for run in range(n_runs):
        temp_name = 'run{}'.format(run+1)
        ex_temp_pn.append(ex_dict_pn[temp_name][turn])
        ey_temp_pn.append(ey_dict_pn[temp_name][turn])
        ex_temp_an.append(ex_dict_an[temp_name][turn])
        ey_temp_an.append(ey_dict_an[temp_name][turn])
    # calculate and append the mean of the emittance value for every turn
    ex_mean_pn.append(np.mean(ex_temp_pn))
    ey_mean_pn.append(np.mean(ey_temp_pn))
    ex_mean_an.append(np.mean(ex_temp_an))
    ey_mean_an.append(np.mean(ey_temp_an))
    # calculate and append the standard deviation of the emittance value for every turn
    ex_std_pn.append(np.std(ex_temp_pn))
    ey_std_pn.append(np.std(ey_temp_pn))
    ex_std_an.append(np.std(ex_temp_an))
    ey_std_an.append(np.std(ey_temp_an))

# %% [markdown]
# #### 3) Convert turns to time [s]

# %%
separationTime = 1 / f_rev * decTurns #There are decTurns revolutions before each recording of data
tspan = (np.arange(n_turns / decTurns) + 1.0) * separationTime #total time spanned by the simulation

# %% [markdown]
# #### 4) Plot evolution of the H (horizontal emittance) emittance

# %%
plt.plot(tspan, np.array(ex_mean_pn)*1e6, c='C0')
plt.plot(tspan, np.array(ex_mean_an)*1e6, c='C1')
plt.plot(2,2,c='C0',  label = 'phase noise', linewidth = 3)    
plt.plot(2,2,c='C1',  label = 'amplitude noise', linewidth = 3)    
plt.xlabel('time [s]')
plt.ylabel(r'$\epsilon_x [\mu m]$')
plt.title('H plane')
plt.legend(loc=0)
plt.grid()
plt.tight_layout()
savefig = False
if savefig:
    plt.savefig('H_270GeV_SPS_noCC_ANvsPN1e-8_VRF2_37MV_1e5Nb_{}turns_mean{}runs.png'.format(n_turns, n_runs))

# %% [markdown]
# #### 5) Plot evolution of the V (vertical emittance) emittance

# %%
plt.plot(tspan, ey_mean_pn/ey_mean_pn[0], c='C0')
plt.plot(tspan, ey_mean_pn/ey_mean_pn[0], c='C1')    
plt.plot(1,1,c='C0',  label = 'phase noise', linewidth = 3)    
plt.plot(1,1,c='C1',  label = 'amplitude noise', linewidth = 3)    
plt.xlabel('time [s]')
plt.ylabel(r'$\epsilon_y [\mu m]$')
plt.legend(loc=0)
plt.grid()
plt.tight_layout()
savefig = False
if savefig:
    plt.savefig('V_emittance_growth_270GeV_SPS_noCC_ANvsPN1e-8_VRF2_37MV_1e5Nb_{}turns_mean{}runs.png'.format(n_turns, n_runs))

# %% [markdown]
# #### 6) Plot evolution of the standard deviation $\sigma$ of the emittance values (in the horizontal plane)

# %%
plt.plot(tspan, np.array(ex_std_an)*int(1e6), c='C1')  
plt.plot(tspan, np.array(ex_std_pn)*1e6, c='C0') 
plt.plot(0,0,c='C0',  label = 'phase noise', linewidth = 3)    
plt.plot(0,0,c='C1',  label = 'amplitude noise', linewidth = 3)  
plt.xlabel('time [s]')
plt.ylabel(r'$\sigma_x [\mu m]$')
plt.legend(loc=0)
plt.grid()
plt.tight_layout()
savefig = False
if savefig:
    plt.savefig('H_std_270GeV_SPS_noCC_ANvsPN1e-8_VRF2_37MV_1e5Nb_{}turns_mean{}runs.png'.format(n_turns, n_runs))

# %% [markdown]
# #### 7) Calculate the emittance growth rate via a linear fit
# - Polynomial fit. The degree of the fitting polynomial is 1.
# - V plane only

# %%
# linear fit
[m_pn, b_pn], cov_pn = np.polyfit(tspan, ex_mean_pn, 1, cov=True)
[m_an, b_an], cov_an = np.polyfit(tspan, ex_mean_an, 1, cov=True)
# compute the error of the gradient of the fit slope
err_pn = np.sqrt(np.diag(cov_pn))
err_an = np.sqrt(np.diag(cov_an))

# %%
plt.plot(tspan, np.array(ex_mean_pn)*1e6, c='C0')
plt.plot(tspan, (m_pn*tspan+b_pn)*1e6, c = 'C0', label='phase noise, dey/dt={0:.2f}'.format(m_pn*1e9)+'$\pm$'+'{0:.2f} nm/s'.format(err_pn[0]*1e9), linewidth = 3)
plt.plot(tspan, np.array(ex_mean_an)*1e6, c='C1')  
plt.plot(tspan, (m_an*tspan+b_an)*1e6, c = 'C1', label='amplitude noise, dey/dt={0:.2f}'.format(m_an*1e9)+'$\pm$'+'{0:.2f} nm/s'.format(err_an[0]*1e9), linewidth = 3)

plt.xlabel('time [s]')
plt.ylabel(r'$\epsilon_x [\mu m]$')
plt.legend(loc=4)
plt.grid()
plt.tight_layout()
savefig = False
if savefig:
    plt.savefig('H_emittance_growth_rate_270GeV_SPS_noCC_ANvsPN1e-8_VRF2_37MV_1e5Nb_{}turns_mean{}runs.png'.format(n_turns, n_runs))
