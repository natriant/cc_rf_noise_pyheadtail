# %%
import csv
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
params = {'legend.fontsize': 20,
          'figure.figsize': (9.5, 8.5),
          'axes.labelsize': 27,
          'axes.titlesize': 23,
          'xtick.labelsize': 27,
          'ytick.labelsize': 27,
          'image.cmap': 'jet',
          'lines.linewidth': 1,
          'lines.markersize': 5,
          'font.family': 'sans-serif'}

plt.rc('text', usetex=False)
plt.rc('font', family='serif')
plt.rcParams.update(params)

# %%
n_runs = 20 # number of runs that the simulation was repeated
n_turns = int(4e5)            # number of cycles to run the simulation for
decTurns = int(100)           # how often to record data
circumference  = 6911.5623 # [m]
f_rev           = 299792458/circumference  # [Hz] The revolution frequency of the machine

# %%
path_to_data = '/afs/cern.ch/work/n/natriant/private/pyheadtail_example_crabcavity/'
type_of_noise = 'PN'
dataset1= 'PN_mytst1'
dataset2 = 'PN_myteest1'

# %%
meanX1, meanY1, meanXsq1, meanYsq1, emitX1, emitY1 = np.loadtxt(path_to_data+dataset1+'/file.txt', delimiter = ",", unpack = True)

# %%
meanX2, meanY2, meanXsq2, meanYsq2, emitX2, emitY2 = np.loadtxt(path_to_data+dataset2+'/file.txt', delimiter = ",", unpack = True)

# %%
plt.plot(emitY1)
plt.plot(emitY2)

# %%
plt.plot(meanY1)
plt.plot(meanY2)

# %%
plt.plot(emitX1)
plt.plot(emitX2)
