# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/afs/cern.ch/work/n/natriant/private/pyheadtail_example_crabcavity/AN_mytest_check_tune_spread/'

# %%
Qy1_list, Qy2_list, Qx1_list, Qx2_list, emitX, emitY = np.loadtxt(path+'file.txt', delimiter = ",", unpack = True)

# %%
plt.plot(Qx1_list, Qy1_list, '.' )
plt.plot(Qx2_list, Qy2_list, '.')

# %%
plt.plot(np.arange(len(emitY)), np.array(emitY)*1e6)

# %%
plt.plot(np.arange(len(emitY)), np.array(emitX)*1e6)
